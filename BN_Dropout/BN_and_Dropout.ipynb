# %% [markdown]
# <a href="https://colab.research.google.com/github/wtsyang/dl-reproducibility-project/blob/batch_norm/cnnTrain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Mount Google Drive
from google.colab import drive # import drive from google colab

ROOT = "/content/drive"     # default location for the drive
print(ROOT)                 # print content of ROOT (Optional)

drive.mount(ROOT)           # we mount the google drive at /content/drive
# Out:
# /content/drive
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
from google.colab import files

uploaded = files.upload()
# Out:
#      <input type="file" id="files-2fbc4738-dbf5-408f-8c47-8e2c498cf069" name="files[]" multiple disabled />
#      <output id="result-2fbc4738-dbf5-408f-8c47-8e2c498cf069">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Model.py to Model.py

# %%
from Model import Model

# %%
try:
    from torchsummary import summary
except ModuleNotFoundError:
    # !pip install -q torchsummary
    from torchsummary import summary

# %%
try:
    import torch
except ModuleNotFoundError:
    from os import path
    from wheel.pep425tags import get_abbr_impl, get_impl_ver, get_abi_tag
    platform = '{}{}-{}'.format(get_abbr_impl(), get_impl_ver(), get_abi_tag())

    accelerator = 'cu80' if path.exists('/opt/bin/nvidia-smi') else 'cpu'

    # !pip install -q http://download.pytorch.org/whl/{accelerator}/torch-0.3.1-{platform}-linux_x86_64.whl
    import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.autograd import Variable

# %%
try:
    import torchvision
except ModuleNotFoundError:
    # !pip install -q torchvision

from torchvision import datasets, transforms

# %%
cuda = True
train_batch_size = 256
test_batch_size = 124
best_loss = float("inf")
best_epoch = -1
dataset_path = './cifar10'
gsync_save = True

# %%
if gsync_save:
    try:
        import utils
    except ModuleNotFoundError:
        # !wget https://raw.githubusercontent.com/StefOe/colab-pytorch-utils/HEAD/utils.py
        import utils

    gsync = utils.GDriveSync()
# Out:
# --2020-03-23 10:19:48--  https://raw.githubusercontent.com/StefOe/colab-pytorch-utils/HEAD/utils.py
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4519 (4.4K) [text/plain]
# Saving to: ‘utils.py’
#
# utils.py            100%[===================>]   4.41K  --.-KB/s    in 0s
#
# 2020-03-23 10:19:48 (80.4 MB/s) - ‘utils.py’ saved [4519/4519]
#
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.38.0)

# %%
cuda = cuda and torch.cuda.is_available()
trainset = datasets.CIFAR10(root=dataset_path, train=True, download=True)
train_mean = trainset.data.mean(axis=(0,1,2))/255  # [0.49139968  0.48215841  0.44653091]
train_std = trainset.data.std(axis=(0,1,2))/255  # [0.24703223  0.24348513  0.26158784]
transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
    transforms.Normalize(train_mean, train_std),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
    transforms.Normalize(train_mean, train_std),
])
kwargs = {'num_workers': 1, 'pin_memory': True} if cuda else {}
train_loader = torch.utils.data.DataLoader(datasets.CIFAR10(
    root=dataset_path, train=True, download=True,
    transform=transform_train),
    batch_size=train_batch_size, shuffle=True, **kwargs)
test_loader = torch.utils.data.DataLoader(
    datasets.CIFAR10(root=dataset_path, train=False, download=True,
    transform=transform_test),
    batch_size=test_batch_size, shuffle=False, **kwargs)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./cifar10/cifar-10-python.tar.gz
# HBox(children=(IntProgress(value=1, bar_style='info', max=1), HTML(value='')))
# Extracting ./cifar10/cifar-10-python.tar.gz to ./cifar10
# Files already downloaded and verified
# Files already downloaded and verified

# %%
def train(epoch):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        if cuda:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)

        optimizer.zero_grad()
        output = model(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
        if batch_idx % 100 == 0:
            print('Train Epoch: {} [{}/{} ({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, batch_idx * len(data), len(train_loader.dataset),
                100. * batch_idx / len(train_loader), loss.data))

# %%
def test(epoch, best_loss, best_epoch, lr):
    model.eval()
    test_loss = 0
    correct = 0
    for data, target in test_loader:
        if cuda:
            data, target = data.cuda(), target.cuda()
        data, target = Variable(data), Variable(target)

        output = model(data)
        # sum up batch loss
        test_loss += criterion(output, target).data
        # get the index of the max log-probability
        pred = output.data.max(1, keepdim=True)[1]
        correct += pred.eq(target.data.view_as(pred)).long().cpu().sum()

    test_loss /= len(test_loader.dataset)
    print(
        '\nTest set: Average loss: {:.4f}, Accuracy: {}/{} ({:.0f}%)\n'.format(
            test_loss, correct, len(test_loader.dataset), 100. * correct /
            len(test_loader.dataset)))
    
    if test_loss < best_loss:
        best_epoch = epoch
        best_loss = test_loss
        torch.save(model, "best_"+str(lr)+".pt")
        try:
          if gsync_save:
              gsync.update_file_to_folder("best_"+str(lr)+".pt")
        except:
          print('Failed to gsync_save.')

        try:
          model_save_name = 'best_'+str(lr)
          path = F"/content/drive/My Drive/dl-reproducibility-project/model/{model_save_name}" 
          torch.save(model.state_dict(), path+'.epoch-{}.pt'.format(epoch))
        except:
          print('Failed to save best model to personal google drive')

    return best_loss, best_epoch, correct

# %%
try:
  os.makedirs('/content/drive/My Drive/dl-reproducibility-project/model/')
except:
  print('')

# %%
for lr in [0.1,0.05,0.01]:
  print("Training with ", lr)

  
  try: 
    del model
  except:
    print('')
  
  # Maybe it's redundant 
  try:
    del criterion
    del optimizer
    del scheduler
  except:
    print('')
  
  try:
    torch.cuda.empty_cache()
  except:
    print('')
  
  #
  # Chnage Here
  #
  # Choose Model A by basemodel=[True, False, False] and choose B by basemodel=[False, True, False]
  # Choose the modification by modifiedModel=[True, False, False, False]. The first one is the model without any modification.
  # The scecond one is the strided. The third: ConvPool. The last: All CNN.
  model = Model(BN=True)
  if cuda:
      model.cuda()

  criterion = nn.CrossEntropyLoss()
  optimizer = optim.SGD(model.parameters(), lr=lr, momentum=0.9)
  scheduler = optim.lr_scheduler.MultiStepLR(
      optimizer, milestones=[200, 250, 300], gamma=0.1)
  print(model)
  summary(model.model, input_size=(3, 32, 32))
  for epoch in range(350):
      scheduler.step()
      train(epoch)
      best_loss, best_epoch, acc = test(epoch, best_loss, best_epoch, lr)
      if (epoch>100)&(acc.item()>0)&((acc.item()/len(test_loader.dataset))<=0.1):
        print("Stop at acc of test set:",acc.item()/len(test_loader.dataset))
        break
  # if in Google Colab, download your model with this
  #from google.colab import files
  #files.download("best_"+str(lr)+"pt")
# Out:
# Training with  0.1
#
#
# Model(
#   (model): Sequential(
#     (0): Dropout(p=0.2, inplace=False)
#     (1): Conv2d(3, 96, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#     (2): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (3): ReLU()
#     (4): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): Dropout(p=0.5, inplace=False)
#     (6): Conv2d(96, 192, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#     (7): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (8): ReLU()
#     (9): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (10): Dropout(p=0.5, inplace=False)
#     (11): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (12): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (13): ReLU()
#     (14): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#     (15): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (16): ReLU()
#     (17): Conv2d(192, 10, kernel_size=(1, 1), stride=(1, 1))
#     (18): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (19): ReLU()
#     (20): AdaptiveAvgPool2d(output_size=1)
#     (21): Flatten()
#   )
#   (conv_3_192_192_1): Conv2d(192, 192, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#   (conv_1_192_192): Conv2d(192, 192, kernel_size=(1, 1), stride=(1, 1))
#   (conv_1_192_class): Conv2d(192, 10, kernel_size=(1, 1), stride=(1, 1))
#   (BN_96): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_192): BatchNorm2d(192, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (BN_class): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (maxP): MaxPool2d(kernel_size=3, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (softMax): Softmax(dim=None)
#   (flatten): Flatten()
#   (dropOut_2): Dropout(p=0.2, inplace=False)
#   (dropOut_5): Dropout(p=0.5, inplace=False)
#   (relu): ReLU()
#   (avgPooling): AdaptiveAvgPool2d(output_size=1)
#   (conv_5_Input_96_1): Conv2d(3, 96, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
#   (conv_5_96_192_1): Conv2d(96, 192, kernel_size=(5, 5), stride=(1, 1), padding=(1, 1))
# )
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#            Dropout-1            [-1, 3, 32, 32]               0
#             Conv2d-2           [-1, 96, 30, 30]           7,296
#        BatchNorm2d-3           [-1, 96, 30, 30]             192
#               ReLU-4           [-1, 96, 30, 30]               0
#          MaxPool2d-5           [-1, 96, 14, 14]               0
#            Dropout-6           [-1, 96, 14, 14]               0
#             Conv2d-7          [-1, 192, 12, 12]         460,992
#        BatchNorm2d-8          [-1, 192, 12, 12]             384
#               ReLU-9          [-1, 192, 12, 12]               0
#         MaxPool2d-10            [-1, 192, 5, 5]               0
#           Dropout-11            [-1, 192, 5, 5]               0
#            Conv2d-12            [-1, 192, 5, 5]         331,968
#       BatchNorm2d-13            [-1, 192, 5, 5]             384
#              ReLU-14            [-1, 192, 5, 5]               0
#            Conv2d-15            [-1, 192, 5, 5]          37,056
#       BatchNorm2d-16            [-1, 192, 5, 5]             384
#              ReLU-17            [-1, 192, 5, 5]               0
#            Conv2d-18             [-1, 10, 5, 5]           1,930
#       BatchNorm2d-19             [-1, 10, 5, 5]              20
#              ReLU-20             [-1, 10, 5, 5]               0
# AdaptiveAvgPool2d-21             [-1, 10, 1, 1]               0
#           Flatten-22                   [-1, 10]               0
# ================================================================
# Total params: 840,606
# Trainable params: 840,606
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.01
# Forward/backward pass size (MB): 3.22
# Params size (MB): 3.21
# Estimated Total Size (MB): 6.44
# ----------------------------------------------------------------
# /usr/local/lib/python3.6/dist-packages/torch/optim/lr_scheduler.py:122: UserWarning: Detected call of `lr_scheduler.step()` before `optimizer.step()`. In PyTorch 1.1.0 and later, you should call them in the opposite order: `optimizer.step()` before `lr_scheduler.step()`.  Failure to do this will result in PyTorch skipping the first value of the learning rate schedule. See more details at https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate
#   "https://pytorch.org/docs/stable/optim.html#how-to-adjust-learning-rate", UserWarning)
# Train Epoch: 0 [0/50000 (0%)]	Loss: 2.308620
# Train Epoch: 0 [25600/50000 (51%)]	Loss: 1.643213
#
# Test set: Average loss: 0.0160, Accuracy: 2619/10000 (26%)
# Uploading file best_0.1.pt: 100%|██████████| 100/100 [00:01<00:00, 59.26it/s]
# Train Epoch: 1 [0/50000 (0%)]	Loss: 1.439080
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.326062
#
# Test set: Average loss: 0.0166, Accuracy: 2184/10000 (22%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.276588
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.184089
#
# Test set: Average loss: 0.0148, Accuracy: 3481/10000 (35%)
# Uploading file best_0.1.pt: 100%|██████████| 100/100 [00:01<00:00, 56.26it/s]
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.088955
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.115658
#
# Test set: Average loss: 0.0147, Accuracy: 3007/10000 (30%)
# Uploading file best_0.1.pt: 100%|██████████| 100/100 [00:01<00:00, 55.50it/s]
# Train Epoch: 4 [0/50000 (0%)]	Loss: 0.974059
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.017117
#
# Test set: Average loss: 0.0159, Accuracy: 2337/10000 (23%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.025668
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 0.992393
#
# Test set: Average loss: 0.0160, Accuracy: 2234/10000 (22%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.010830
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.006120
#
# Test set: Average loss: 0.0173, Accuracy: 1148/10000 (11%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 0.876055
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.072038
#
# Test set: Average loss: 0.0177, Accuracy: 1097/10000 (11%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 0.877935
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 0.874225
#
# Test set: Average loss: 0.0171, Accuracy: 1174/10000 (12%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 0.764129
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.060742
#
# Test set: Average loss: 0.0175, Accuracy: 1354/10000 (14%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 0.836670
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 0.795282
#
# Test set: Average loss: 0.0175, Accuracy: 1061/10000 (11%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.815828
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 0.793533
#
# Test set: Average loss: 0.0177, Accuracy: 1094/10000 (11%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 0.894782
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 0.915667
#
# Test set: Average loss: 0.0178, Accuracy: 1001/10000 (10%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.943554
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 0.776783
#
# Test set: Average loss: 0.0182, Accuracy: 1013/10000 (10%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.844079
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 0.767011
#
# Test set: Average loss: 0.0181, Accuracy: 1019/10000 (10%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.854024
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 0.753443
#
# Test set: Average loss: 0.0195, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 0.723355
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.741540
#
# Test set: Average loss: 0.0187, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 0.769757
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 0.643346
#
# Test set: Average loss: 0.0189, Accuracy: 1089/10000 (11%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.822807
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 0.662066
#
# Test set: Average loss: 0.0195, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.714592
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 0.751817
#
# Test set: Average loss: 0.0185, Accuracy: 1005/10000 (10%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.799337
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.739581
#
# Test set: Average loss: 0.0183, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.791845
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.720021
#
# Test set: Average loss: 0.0188, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.629566
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.641169
#
# Test set: Average loss: 0.0188, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.619757
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.694954
#
# Test set: Average loss: 0.0194, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.686463
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.621271
#
# Test set: Average loss: 0.0192, Accuracy: 1001/10000 (10%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.658486
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.748697
#
# Test set: Average loss: 0.0188, Accuracy: 1039/10000 (10%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.653337
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.771277
#
# Test set: Average loss: 0.0198, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.586773
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.593700
#
# Test set: Average loss: 0.0185, Accuracy: 1003/10000 (10%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.591191
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.700335
#
# Test set: Average loss: 0.0185, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.662142
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.702879
#
# Test set: Average loss: 0.0192, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.736474
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.573318
#
# Test set: Average loss: 0.0189, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.657446
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.653428
#
# Test set: Average loss: 0.0199, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.650316
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.698935
#
# Test set: Average loss: 0.0191, Accuracy: 1003/10000 (10%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.703161
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.661205
#
# Test set: Average loss: 0.0202, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.592858
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.641453
#
# Test set: Average loss: 0.0194, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.612200
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.723569
#
# Test set: Average loss: 0.0188, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.618067
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.594583
#
# Test set: Average loss: 0.0187, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.644625
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.746873
#
# Test set: Average loss: 0.0186, Accuracy: 1008/10000 (10%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.589692
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.614349
#
# Test set: Average loss: 0.0191, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.609762
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.676517
#
# Test set: Average loss: 0.0185, Accuracy: 1008/10000 (10%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.611362
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.665541
#
# Test set: Average loss: 0.0193, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.767469
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.679794
#
# Test set: Average loss: 0.0185, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.654473
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.655177
#
# Test set: Average loss: 0.0189, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.575495
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.725287
#
# Test set: Average loss: 0.0193, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.521450
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.675820
#
# Test set: Average loss: 0.0198, Accuracy: 1010/10000 (10%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.587214
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.414174
#
# Test set: Average loss: 0.0194, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.665500
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.499060
#
# Test set: Average loss: 0.0194, Accuracy: 1044/10000 (10%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.539230
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.540740
#
# Test set: Average loss: 0.0188, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.585885
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.599098
#
# Test set: Average loss: 0.0196, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.607868
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.551538
#
# Test set: Average loss: 0.0186, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.596667
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.620420
#
# Test set: Average loss: 0.0190, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 51 [0/50000 (0%)]	Loss: 0.576296
# Train Epoch: 51 [25600/50000 (51%)]	Loss: 0.712869
#
# Test set: Average loss: 0.0189, Accuracy: 1018/10000 (10%)
#
# Train Epoch: 52 [0/50000 (0%)]	Loss: 0.642611
# Train Epoch: 52 [25600/50000 (51%)]	Loss: 0.594451
#
# Test set: Average loss: 0.0193, Accuracy: 1015/10000 (10%)
#
# Train Epoch: 53 [0/50000 (0%)]	Loss: 0.646333
# Train Epoch: 53 [25600/50000 (51%)]	Loss: 0.657436
#
# Test set: Average loss: 0.0195, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 54 [0/50000 (0%)]	Loss: 0.570612
# Train Epoch: 54 [25600/50000 (51%)]	Loss: 0.564707
#
# Test set: Average loss: 0.0194, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 55 [0/50000 (0%)]	Loss: 0.648540
# Train Epoch: 55 [25600/50000 (51%)]	Loss: 0.571487
#
# Test set: Average loss: 0.0185, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 56 [0/50000 (0%)]	Loss: 0.553755
# Train Epoch: 56 [25600/50000 (51%)]	Loss: 0.537462
#
# Test set: Average loss: 0.0194, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 57 [0/50000 (0%)]	Loss: 0.549626
# Train Epoch: 57 [25600/50000 (51%)]	Loss: 0.585922
#
# Test set: Average loss: 0.0192, Accuracy: 1017/10000 (10%)
#
# Train Epoch: 58 [0/50000 (0%)]	Loss: 0.593805
# Train Epoch: 58 [25600/50000 (51%)]	Loss: 0.638347
#
# Test set: Average loss: 0.0201, Accuracy: 1008/10000 (10%)
#
# Train Epoch: 59 [0/50000 (0%)]	Loss: 0.689951
# Train Epoch: 59 [25600/50000 (51%)]	Loss: 0.593002
#
# Test set: Average loss: 0.0207, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 60 [0/50000 (0%)]	Loss: 0.620945
# Train Epoch: 60 [25600/50000 (51%)]	Loss: 0.463982
#
# Test set: Average loss: 0.0195, Accuracy: 1015/10000 (10%)
#
# Train Epoch: 61 [0/50000 (0%)]	Loss: 0.569358
# Train Epoch: 61 [25600/50000 (51%)]	Loss: 0.565239
#
# Test set: Average loss: 0.0194, Accuracy: 1019/10000 (10%)
#
# Train Epoch: 62 [0/50000 (0%)]	Loss: 0.529576
# Train Epoch: 62 [25600/50000 (51%)]	Loss: 0.596218
#
# Test set: Average loss: 0.0198, Accuracy: 1011/10000 (10%)
#
# Train Epoch: 63 [0/50000 (0%)]	Loss: 0.535087
# Train Epoch: 63 [25600/50000 (51%)]	Loss: 0.585051
#
# Test set: Average loss: 0.0195, Accuracy: 1008/10000 (10%)
#
# Train Epoch: 64 [0/50000 (0%)]	Loss: 0.594714
# Train Epoch: 64 [25600/50000 (51%)]	Loss: 0.551645
#
# Test set: Average loss: 0.0195, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 65 [0/50000 (0%)]	Loss: 0.600660
# Train Epoch: 65 [25600/50000 (51%)]	Loss: 0.645258
#
# Test set: Average loss: 0.0190, Accuracy: 1010/10000 (10%)
#
# Train Epoch: 66 [0/50000 (0%)]	Loss: 0.575401
# Train Epoch: 66 [25600/50000 (51%)]	Loss: 0.628192
#
# Test set: Average loss: 0.0184, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 67 [0/50000 (0%)]	Loss: 0.681599
# Train Epoch: 67 [25600/50000 (51%)]	Loss: 0.570576
#
# Test set: Average loss: 0.0183, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 68 [0/50000 (0%)]	Loss: 0.597884
# Train Epoch: 68 [25600/50000 (51%)]	Loss: 0.531951
#
# Test set: Average loss: 0.0193, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 69 [0/50000 (0%)]	Loss: 0.666470
# Train Epoch: 69 [25600/50000 (51%)]	Loss: 0.642154
#
# Test set: Average loss: 0.0185, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 70 [0/50000 (0%)]	Loss: 0.530920
# Train Epoch: 70 [25600/50000 (51%)]	Loss: 0.489698
#
# Test set: Average loss: 0.0191, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 71 [0/50000 (0%)]	Loss: 0.581772
# Train Epoch: 71 [25600/50000 (51%)]	Loss: 0.558245
#
# Test set: Average loss: 0.0196, Accuracy: 1040/10000 (10%)
#
# Train Epoch: 72 [0/50000 (0%)]	Loss: 0.552425
# Train Epoch: 72 [25600/50000 (51%)]	Loss: 0.498413
#
# Test set: Average loss: 0.0200, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 73 [0/50000 (0%)]	Loss: 0.470367
# Train Epoch: 73 [25600/50000 (51%)]	Loss: 0.560316
#
# Test set: Average loss: 0.0182, Accuracy: 1020/10000 (10%)
#
# Train Epoch: 74 [0/50000 (0%)]	Loss: 0.531859
# Train Epoch: 74 [25600/50000 (51%)]	Loss: 0.537472
#
# Test set: Average loss: 0.0183, Accuracy: 1048/10000 (10%)
#
# Train Epoch: 75 [0/50000 (0%)]	Loss: 0.449350
# Train Epoch: 75 [25600/50000 (51%)]	Loss: 0.555319
#
# Test set: Average loss: 0.0199, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 76 [0/50000 (0%)]	Loss: 0.678363
# Train Epoch: 76 [25600/50000 (51%)]	Loss: 0.606464
#
# Test set: Average loss: 0.0193, Accuracy: 1008/10000 (10%)
#
# Train Epoch: 77 [0/50000 (0%)]	Loss: 0.584812
# Train Epoch: 77 [25600/50000 (51%)]	Loss: 0.556249
#
# Test set: Average loss: 0.0196, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 78 [0/50000 (0%)]	Loss: 0.449964
# Train Epoch: 78 [25600/50000 (51%)]	Loss: 0.529620
#
# Test set: Average loss: 0.0195, Accuracy: 1005/10000 (10%)
#
# Train Epoch: 79 [0/50000 (0%)]	Loss: 0.518177
# Train Epoch: 79 [25600/50000 (51%)]	Loss: 0.538345
#
# Test set: Average loss: 0.0200, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 80 [0/50000 (0%)]	Loss: 0.439693
# Train Epoch: 80 [25600/50000 (51%)]	Loss: 0.585402
#
# Test set: Average loss: 0.0205, Accuracy: 1011/10000 (10%)
#
# Train Epoch: 81 [0/50000 (0%)]	Loss: 0.642625
# Train Epoch: 81 [25600/50000 (51%)]	Loss: 0.613992
#
# Test set: Average loss: 0.0189, Accuracy: 1040/10000 (10%)
#
# Train Epoch: 82 [0/50000 (0%)]	Loss: 0.538180
# Train Epoch: 82 [25600/50000 (51%)]	Loss: 0.596309
#
# Test set: Average loss: 0.0193, Accuracy: 1015/10000 (10%)
#
# Train Epoch: 83 [0/50000 (0%)]	Loss: 0.586077
# Train Epoch: 83 [25600/50000 (51%)]	Loss: 0.548342
#
# Test set: Average loss: 0.0180, Accuracy: 1079/10000 (11%)
#
# Train Epoch: 84 [0/50000 (0%)]	Loss: 0.537106
# Train Epoch: 84 [25600/50000 (51%)]	Loss: 0.511954
#
# Test set: Average loss: 0.0190, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 85 [0/50000 (0%)]	Loss: 0.570402
# Train Epoch: 85 [25600/50000 (51%)]	Loss: 0.614308
#
# Test set: Average loss: 0.0202, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 86 [0/50000 (0%)]	Loss: 0.585116
# Train Epoch: 86 [25600/50000 (51%)]	Loss: 0.467687
#
# Test set: Average loss: 0.0186, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 87 [0/50000 (0%)]	Loss: 0.552798
# Train Epoch: 87 [25600/50000 (51%)]	Loss: 0.713691
#
# Test set: Average loss: 0.0188, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 88 [0/50000 (0%)]	Loss: 0.660571
# Train Epoch: 88 [25600/50000 (51%)]	Loss: 0.528868
#
# Test set: Average loss: 0.0196, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 89 [0/50000 (0%)]	Loss: 0.577305
# Train Epoch: 89 [25600/50000 (51%)]	Loss: 0.549293
#
# Test set: Average loss: 0.0199, Accuracy: 1010/10000 (10%)
#
# Train Epoch: 90 [0/50000 (0%)]	Loss: 0.602205
# Train Epoch: 90 [25600/50000 (51%)]	Loss: 0.568729
#
# Test set: Average loss: 0.0209, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 91 [0/50000 (0%)]	Loss: 0.727559
# Train Epoch: 91 [25600/50000 (51%)]	Loss: 0.519543
#
# Test set: Average loss: 0.0202, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 92 [0/50000 (0%)]	Loss: 0.589275
# Train Epoch: 92 [25600/50000 (51%)]	Loss: 0.505094
#
# Test set: Average loss: 0.0189, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 93 [0/50000 (0%)]	Loss: 0.437265
# Train Epoch: 93 [25600/50000 (51%)]	Loss: 0.507404
#
# Test set: Average loss: 0.0190, Accuracy: 1042/10000 (10%)
#
# Train Epoch: 94 [0/50000 (0%)]	Loss: 0.537715
# Train Epoch: 94 [25600/50000 (51%)]	Loss: 0.563074
#
# Test set: Average loss: 0.0201, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 95 [0/50000 (0%)]	Loss: 0.609041
# Train Epoch: 95 [25600/50000 (51%)]	Loss: 0.489580
#
# Test set: Average loss: 0.0205, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 96 [0/50000 (0%)]	Loss: 0.446476
# Train Epoch: 96 [25600/50000 (51%)]	Loss: 0.545537
#
# Test set: Average loss: 0.0196, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 97 [0/50000 (0%)]	Loss: 0.500401
# Train Epoch: 97 [25600/50000 (51%)]	Loss: 0.559331
#
# Test set: Average loss: 0.0192, Accuracy: 1013/10000 (10%)
#
# Train Epoch: 98 [0/50000 (0%)]	Loss: 0.518981
# Train Epoch: 98 [25600/50000 (51%)]	Loss: 0.539307
#
# Test set: Average loss: 0.0184, Accuracy: 1042/10000 (10%)
#
# Train Epoch: 99 [0/50000 (0%)]	Loss: 0.497912
# Train Epoch: 99 [25600/50000 (51%)]	Loss: 0.522112
#
# Test set: Average loss: 0.0195, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 100 [0/50000 (0%)]	Loss: 0.558289
# Train Epoch: 100 [25600/50000 (51%)]	Loss: 0.648964
#
# Test set: Average loss: 0.0192, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 101 [0/50000 (0%)]	Loss: 0.630598
# Train Epoch: 101 [25600/50000 (51%)]	Loss: 0.551458
#
# Test set: Average loss: 0.0191, Accuracy: 1037/10000 (10%)
#
# Train Epoch: 102 [0/50000 (0%)]	Loss: 0.495153
# Train Epoch: 102 [25600/50000 (51%)]	Loss: 0.523582
#
# Test set: Average loss: 0.0186, Accuracy: 1016/10000 (10%)
#
# Train Epoch: 103 [0/50000 (0%)]	Loss: 0.442939
# Train Epoch: 103 [25600/50000 (51%)]	Loss: 0.546106
#
# Test set: Average loss: 0.0188, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 104 [0/50000 (0%)]	Loss: 0.520668
# Train Epoch: 104 [25600/50000 (51%)]	Loss: 0.468000
#
# Test set: Average loss: 0.0180, Accuracy: 1086/10000 (11%)
#
# Train Epoch: 105 [0/50000 (0%)]	Loss: 0.526410
# Train Epoch: 105 [25600/50000 (51%)]	Loss: 0.563099
#
# Test set: Average loss: 0.0190, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 106 [0/50000 (0%)]	Loss: 0.409595
# Train Epoch: 106 [25600/50000 (51%)]	Loss: 0.509126
#
# Test set: Average loss: 0.0191, Accuracy: 1069/10000 (11%)
#
# Train Epoch: 107 [0/50000 (0%)]	Loss: 0.534455
# Train Epoch: 107 [25600/50000 (51%)]	Loss: 0.505799
#
# Test set: Average loss: 0.0181, Accuracy: 1066/10000 (11%)
#
# Train Epoch: 108 [0/50000 (0%)]	Loss: 0.552991
# Train Epoch: 108 [25600/50000 (51%)]	Loss: 0.562668
#
# Test set: Average loss: 0.0200, Accuracy: 1011/10000 (10%)
#
# Train Epoch: 109 [0/50000 (0%)]	Loss: 0.528262
# Train Epoch: 109 [25600/50000 (51%)]	Loss: 0.531463
#
# Test set: Average loss: 0.0188, Accuracy: 1021/10000 (10%)
#
# Train Epoch: 110 [0/50000 (0%)]	Loss: 0.654531
# Train Epoch: 110 [25600/50000 (51%)]	Loss: 0.522228
#
# Test set: Average loss: 0.0191, Accuracy: 1037/10000 (10%)
#
# Train Epoch: 111 [0/50000 (0%)]	Loss: 0.499344
# Train Epoch: 111 [25600/50000 (51%)]	Loss: 0.398276
#
# Test set: Average loss: 0.0190, Accuracy: 1016/10000 (10%)
#
# Train Epoch: 112 [0/50000 (0%)]	Loss: 0.530435
# Train Epoch: 112 [25600/50000 (51%)]	Loss: 0.525583
#
# Test set: Average loss: 0.0188, Accuracy: 1057/10000 (11%)
#
# Train Epoch: 113 [0/50000 (0%)]	Loss: 0.419086
# Train Epoch: 113 [25600/50000 (51%)]	Loss: 0.497860
#
# Test set: Average loss: 0.0181, Accuracy: 1078/10000 (11%)
#
# Train Epoch: 114 [0/50000 (0%)]	Loss: 0.404855
# Train Epoch: 114 [25600/50000 (51%)]	Loss: 0.419624
#
# Test set: Average loss: 0.0195, Accuracy: 1031/10000 (10%)
#
# Train Epoch: 115 [0/50000 (0%)]	Loss: 0.474041
# Train Epoch: 115 [25600/50000 (51%)]	Loss: 0.448614
#
# Test set: Average loss: 0.0188, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 116 [0/50000 (0%)]	Loss: 0.446524
# Train Epoch: 116 [25600/50000 (51%)]	Loss: 0.467419
#
# Test set: Average loss: 0.0184, Accuracy: 1122/10000 (11%)
#
# Train Epoch: 117 [0/50000 (0%)]	Loss: 0.514324
# Train Epoch: 117 [25600/50000 (51%)]	Loss: 0.417460
#
# Test set: Average loss: 0.0188, Accuracy: 1053/10000 (11%)
#
# Train Epoch: 118 [0/50000 (0%)]	Loss: 0.434541
# Train Epoch: 118 [25600/50000 (51%)]	Loss: 0.428041
#
# Test set: Average loss: 0.0190, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 119 [0/50000 (0%)]	Loss: 0.492130
# Train Epoch: 119 [25600/50000 (51%)]	Loss: 0.454769
#
# Test set: Average loss: 0.0184, Accuracy: 1054/10000 (11%)
#
# Train Epoch: 120 [0/50000 (0%)]	Loss: 0.471071
# Train Epoch: 120 [25600/50000 (51%)]	Loss: 0.461363
#
# Test set: Average loss: 0.0182, Accuracy: 1063/10000 (11%)
#
# Train Epoch: 121 [0/50000 (0%)]	Loss: 0.491699
# Train Epoch: 121 [25600/50000 (51%)]	Loss: 0.478071
#
# Test set: Average loss: 0.0195, Accuracy: 1017/10000 (10%)
#
# Train Epoch: 122 [0/50000 (0%)]	Loss: 0.488842
# Train Epoch: 122 [25600/50000 (51%)]	Loss: 0.477708
#
# Test set: Average loss: 0.0188, Accuracy: 1049/10000 (10%)
#
# Train Epoch: 123 [0/50000 (0%)]	Loss: 0.448895
# Train Epoch: 123 [25600/50000 (51%)]	Loss: 0.464051
#
# Test set: Average loss: 0.0187, Accuracy: 1070/10000 (11%)
#
# Train Epoch: 124 [0/50000 (0%)]	Loss: 0.450274
# Train Epoch: 124 [25600/50000 (51%)]	Loss: 0.526066
#
# Test set: Average loss: 0.0189, Accuracy: 1032/10000 (10%)
#
# Train Epoch: 125 [0/50000 (0%)]	Loss: 0.485434
# Train Epoch: 125 [25600/50000 (51%)]	Loss: 0.601202
#
# Test set: Average loss: 0.0194, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 126 [0/50000 (0%)]	Loss: 0.439238
# Train Epoch: 126 [25600/50000 (51%)]	Loss: 0.455170
#
# Test set: Average loss: 0.0197, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 127 [0/50000 (0%)]	Loss: 0.467016
# Train Epoch: 127 [25600/50000 (51%)]	Loss: 0.552636
#
# Test set: Average loss: 0.0190, Accuracy: 1047/10000 (10%)
#
# Train Epoch: 128 [0/50000 (0%)]	Loss: 0.407245
# Train Epoch: 128 [25600/50000 (51%)]	Loss: 0.572598
#
# Test set: Average loss: 0.0197, Accuracy: 1011/10000 (10%)
#
# Train Epoch: 129 [0/50000 (0%)]	Loss: 0.481565
# Train Epoch: 129 [25600/50000 (51%)]	Loss: 0.489536
#
# Test set: Average loss: 0.0203, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 130 [0/50000 (0%)]	Loss: 0.529556
# Train Epoch: 130 [25600/50000 (51%)]	Loss: 0.528017
#
# Test set: Average loss: 0.0202, Accuracy: 1010/10000 (10%)
#
# Train Epoch: 131 [0/50000 (0%)]	Loss: 0.403055
# Train Epoch: 131 [25600/50000 (51%)]	Loss: 0.531460
#
# Test set: Average loss: 0.0205, Accuracy: 1022/10000 (10%)
#
# Train Epoch: 132 [0/50000 (0%)]	Loss: 0.602570
# Train Epoch: 132 [25600/50000 (51%)]	Loss: 0.437361
#
# Test set: Average loss: 0.0209, Accuracy: 1015/10000 (10%)
#
# Train Epoch: 133 [0/50000 (0%)]	Loss: 0.543042
# Train Epoch: 133 [25600/50000 (51%)]	Loss: 0.507612
#
# Test set: Average loss: 0.0198, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 134 [0/50000 (0%)]	Loss: 0.504036
# Train Epoch: 134 [25600/50000 (51%)]	Loss: 0.569082
#
# Test set: Average loss: 0.0197, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 135 [0/50000 (0%)]	Loss: 0.433180
# Train Epoch: 135 [25600/50000 (51%)]	Loss: 0.489214
#
# Test set: Average loss: 0.0186, Accuracy: 1054/10000 (11%)
#
# Train Epoch: 136 [0/50000 (0%)]	Loss: 0.442134
# Train Epoch: 136 [25600/50000 (51%)]	Loss: 0.525638
#
# Test set: Average loss: 0.0190, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 137 [0/50000 (0%)]	Loss: 0.501770
# Train Epoch: 137 [25600/50000 (51%)]	Loss: 0.580919
#
# Test set: Average loss: 0.0189, Accuracy: 1080/10000 (11%)
#
# Train Epoch: 138 [0/50000 (0%)]	Loss: 0.576114
# Train Epoch: 138 [25600/50000 (51%)]	Loss: 0.424371
#
# Test set: Average loss: 0.0199, Accuracy: 1057/10000 (11%)
#
# Train Epoch: 139 [0/50000 (0%)]	Loss: 0.423259
# Train Epoch: 139 [25600/50000 (51%)]	Loss: 0.552720
#
# Test set: Average loss: 0.0201, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 140 [0/50000 (0%)]	Loss: 0.465589
# Train Epoch: 140 [25600/50000 (51%)]	Loss: 0.549936
#
# Test set: Average loss: 0.0208, Accuracy: 1018/10000 (10%)
#
# Train Epoch: 141 [0/50000 (0%)]	Loss: 0.431359
# Train Epoch: 141 [25600/50000 (51%)]	Loss: 0.547336
#
# Test set: Average loss: 0.0193, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 142 [0/50000 (0%)]	Loss: 0.366357
# Train Epoch: 142 [25600/50000 (51%)]	Loss: 0.480198
#
# Test set: Average loss: 0.0198, Accuracy: 1015/10000 (10%)
#
# Train Epoch: 143 [0/50000 (0%)]	Loss: 0.451616
# Train Epoch: 143 [25600/50000 (51%)]	Loss: 0.595932
#
# Test set: Average loss: 0.0199, Accuracy: 1031/10000 (10%)
#
# Train Epoch: 144 [0/50000 (0%)]	Loss: 0.605132
# Train Epoch: 144 [25600/50000 (51%)]	Loss: 0.367699
#
# Test set: Average loss: 0.0186, Accuracy: 1077/10000 (11%)
#
# Train Epoch: 145 [0/50000 (0%)]	Loss: 0.557989
# Train Epoch: 145 [25600/50000 (51%)]	Loss: 0.553217
#
# Test set: Average loss: 0.0188, Accuracy: 1044/10000 (10%)
#
# Train Epoch: 146 [0/50000 (0%)]	Loss: 0.453230
# Train Epoch: 146 [25600/50000 (51%)]	Loss: 0.541116
#
# Test set: Average loss: 0.0195, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 147 [0/50000 (0%)]	Loss: 0.447924
# Train Epoch: 147 [25600/50000 (51%)]	Loss: 0.573845
#
# Test set: Average loss: 0.0193, Accuracy: 1034/10000 (10%)
#
# Train Epoch: 148 [0/50000 (0%)]	Loss: 0.483379
# Train Epoch: 148 [25600/50000 (51%)]	Loss: 0.362418
#
# Test set: Average loss: 0.0196, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 149 [0/50000 (0%)]	Loss: 0.480688
# Train Epoch: 149 [25600/50000 (51%)]	Loss: 0.447167
#
# Test set: Average loss: 0.0195, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 150 [0/50000 (0%)]	Loss: 0.434956
# Train Epoch: 150 [25600/50000 (51%)]	Loss: 0.497985
#
# Test set: Average loss: 0.0188, Accuracy: 1062/10000 (11%)
#
# Train Epoch: 151 [0/50000 (0%)]	Loss: 0.487740
# Train Epoch: 151 [25600/50000 (51%)]	Loss: 0.510534
#
# Test set: Average loss: 0.0196, Accuracy: 1046/10000 (10%)
#
# Train Epoch: 152 [0/50000 (0%)]	Loss: 0.396080
# Train Epoch: 152 [25600/50000 (51%)]	Loss: 0.452761
#
# Test set: Average loss: 0.0196, Accuracy: 1043/10000 (10%)
#
# Train Epoch: 153 [0/50000 (0%)]	Loss: 0.457097
# Train Epoch: 153 [25600/50000 (51%)]	Loss: 0.406927
#
# Test set: Average loss: 0.0208, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 154 [0/50000 (0%)]	Loss: 0.501345
# Train Epoch: 154 [25600/50000 (51%)]	Loss: 0.492590
#
# Test set: Average loss: 0.0192, Accuracy: 1053/10000 (11%)
#
# Train Epoch: 155 [0/50000 (0%)]	Loss: 0.457564
# Train Epoch: 155 [25600/50000 (51%)]	Loss: 0.481704
#
# Test set: Average loss: 0.0204, Accuracy: 1041/10000 (10%)
#
# Train Epoch: 156 [0/50000 (0%)]	Loss: 0.495752
# Train Epoch: 156 [25600/50000 (51%)]	Loss: 0.457871
#
# Test set: Average loss: 0.0204, Accuracy: 1040/10000 (10%)
#
# Train Epoch: 157 [0/50000 (0%)]	Loss: 0.444346
# Train Epoch: 157 [25600/50000 (51%)]	Loss: 0.421830
#
# Test set: Average loss: 0.0191, Accuracy: 1041/10000 (10%)
#
# Train Epoch: 158 [0/50000 (0%)]	Loss: 0.494364
# Train Epoch: 158 [25600/50000 (51%)]	Loss: 0.534260
#
# Test set: Average loss: 0.0190, Accuracy: 1071/10000 (11%)
#
# Train Epoch: 159 [0/50000 (0%)]	Loss: 0.492861
# Train Epoch: 159 [25600/50000 (51%)]	Loss: 0.503332
#
# Test set: Average loss: 0.0200, Accuracy: 1017/10000 (10%)
#
# Train Epoch: 160 [0/50000 (0%)]	Loss: 0.447388
# Train Epoch: 160 [25600/50000 (51%)]	Loss: 0.415259
#
# Test set: Average loss: 0.0199, Accuracy: 1032/10000 (10%)
#
# Train Epoch: 161 [0/50000 (0%)]	Loss: 0.435025
# Train Epoch: 161 [25600/50000 (51%)]	Loss: 0.549718
#
# Test set: Average loss: 0.0191, Accuracy: 1056/10000 (11%)
#
# Train Epoch: 162 [0/50000 (0%)]	Loss: 0.478258
# Train Epoch: 162 [25600/50000 (51%)]	Loss: 0.521296
#
# Test set: Average loss: 0.0200, Accuracy: 1020/10000 (10%)
#
# Train Epoch: 163 [0/50000 (0%)]	Loss: 0.468238
# Train Epoch: 163 [25600/50000 (51%)]	Loss: 0.472221
#
# Test set: Average loss: 0.0195, Accuracy: 1046/10000 (10%)
#
# Train Epoch: 164 [0/50000 (0%)]	Loss: 0.581842
# Train Epoch: 164 [25600/50000 (51%)]	Loss: 0.512054
#
# Test set: Average loss: 0.0190, Accuracy: 1067/10000 (11%)
#
# Train Epoch: 165 [0/50000 (0%)]	Loss: 0.524469
# Train Epoch: 165 [25600/50000 (51%)]	Loss: 0.512798
#
# Test set: Average loss: 0.0194, Accuracy: 1084/10000 (11%)
#
# Train Epoch: 166 [0/50000 (0%)]	Loss: 0.381859
# Train Epoch: 166 [25600/50000 (51%)]	Loss: 0.470795
#
# Test set: Average loss: 0.0194, Accuracy: 1045/10000 (10%)
#
# Train Epoch: 167 [0/50000 (0%)]	Loss: 0.531259
# Train Epoch: 167 [25600/50000 (51%)]	Loss: 0.376747
#
# Test set: Average loss: 0.0197, Accuracy: 1014/10000 (10%)
#
# Train Epoch: 168 [0/50000 (0%)]	Loss: 0.507965
# Train Epoch: 168 [25600/50000 (51%)]	Loss: 0.555311
#
# Test set: Average loss: 0.0190, Accuracy: 1079/10000 (11%)
#
# Train Epoch: 169 [0/50000 (0%)]	Loss: 0.468572
# Train Epoch: 169 [25600/50000 (51%)]	Loss: 0.432962
#
# Test set: Average loss: 0.0194, Accuracy: 1081/10000 (11%)
#
# Train Epoch: 170 [0/50000 (0%)]	Loss: 0.499282
# Train Epoch: 170 [25600/50000 (51%)]	Loss: 0.489745
#
# Test set: Average loss: 0.0205, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 171 [0/50000 (0%)]	Loss: 0.458346
# Train Epoch: 171 [25600/50000 (51%)]	Loss: 0.506213
#
# Test set: Average loss: 0.0201, Accuracy: 1076/10000 (11%)
#
# Train Epoch: 172 [0/50000 (0%)]	Loss: 0.319966
# Train Epoch: 172 [25600/50000 (51%)]	Loss: 0.417153
#
# Test set: Average loss: 0.0203, Accuracy: 1022/10000 (10%)
#
# Train Epoch: 173 [0/50000 (0%)]	Loss: 0.477555
# Train Epoch: 173 [25600/50000 (51%)]	Loss: 0.524133
#
# Test set: Average loss: 0.0212, Accuracy: 1013/10000 (10%)
#
# Train Epoch: 174 [0/50000 (0%)]	Loss: 0.440494
# Train Epoch: 174 [25600/50000 (51%)]	Loss: 0.451611
#
# Test set: Average loss: 0.0198, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 175 [0/50000 (0%)]	Loss: 0.514620
# Train Epoch: 175 [25600/50000 (51%)]	Loss: 0.441912
#
# Test set: Average loss: 0.0188, Accuracy: 1039/10000 (10%)
#
# Train Epoch: 176 [0/50000 (0%)]	Loss: 0.433764
# Train Epoch: 176 [25600/50000 (51%)]	Loss: 0.474296
#
# Test set: Average loss: 0.0196, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 177 [0/50000 (0%)]	Loss: 0.576767
# Train Epoch: 177 [25600/50000 (51%)]	Loss: 0.483198
#
# Test set: Average loss: 0.0208, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 178 [0/50000 (0%)]	Loss: 0.424932
# Train Epoch: 178 [25600/50000 (51%)]	Loss: 0.528948
#
# Test set: Average loss: 0.0188, Accuracy: 1047/10000 (10%)
#
# Train Epoch: 179 [0/50000 (0%)]	Loss: 0.460527
# Train Epoch: 179 [25600/50000 (51%)]	Loss: 0.438121
#
# Test set: Average loss: 0.0197, Accuracy: 1077/10000 (11%)
#
# Train Epoch: 180 [0/50000 (0%)]	Loss: 0.529749
# Train Epoch: 180 [25600/50000 (51%)]	Loss: 0.397873
#
# Test set: Average loss: 0.0202, Accuracy: 1039/10000 (10%)
#
# Train Epoch: 181 [0/50000 (0%)]	Loss: 0.451372
# Train Epoch: 181 [25600/50000 (51%)]	Loss: 0.406252
#
# Test set: Average loss: 0.0217, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 182 [0/50000 (0%)]	Loss: 0.528781
# Train Epoch: 182 [25600/50000 (51%)]	Loss: 0.492295
#
# Test set: Average loss: 0.0185, Accuracy: 1102/10000 (11%)
#
# Train Epoch: 183 [0/50000 (0%)]	Loss: 0.377189
# Train Epoch: 183 [25600/50000 (51%)]	Loss: 0.415301
#
# Test set: Average loss: 0.0196, Accuracy: 1067/10000 (11%)
#
# Train Epoch: 184 [0/50000 (0%)]	Loss: 0.468097
# Train Epoch: 184 [25600/50000 (51%)]	Loss: 0.464608
#
# Test set: Average loss: 0.0199, Accuracy: 1053/10000 (11%)
#
# Train Epoch: 185 [0/50000 (0%)]	Loss: 0.494021
# Train Epoch: 185 [25600/50000 (51%)]	Loss: 0.517677
#
# Test set: Average loss: 0.0200, Accuracy: 1061/10000 (11%)
#
# Train Epoch: 186 [0/50000 (0%)]	Loss: 0.444195
# Train Epoch: 186 [25600/50000 (51%)]	Loss: 0.446622
#
# Test set: Average loss: 0.0196, Accuracy: 1040/10000 (10%)
#
# Train Epoch: 187 [0/50000 (0%)]	Loss: 0.413239
# Train Epoch: 187 [25600/50000 (51%)]	Loss: 0.369857
#
# Test set: Average loss: 0.0196, Accuracy: 1076/10000 (11%)
#
# Train Epoch: 188 [0/50000 (0%)]	Loss: 0.437461
# Train Epoch: 188 [25600/50000 (51%)]	Loss: 0.394060
#
# Test set: Average loss: 0.0198, Accuracy: 1059/10000 (11%)
#
# Train Epoch: 189 [0/50000 (0%)]	Loss: 0.323635
# Train Epoch: 189 [25600/50000 (51%)]	Loss: 0.474728
#
# Test set: Average loss: 0.0206, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 190 [0/50000 (0%)]	Loss: 0.353526
# Train Epoch: 190 [25600/50000 (51%)]	Loss: 0.422001
#
# Test set: Average loss: 0.0202, Accuracy: 1044/10000 (10%)
#
# Train Epoch: 191 [0/50000 (0%)]	Loss: 0.419184
# Train Epoch: 191 [25600/50000 (51%)]	Loss: 0.340085
#
# Test set: Average loss: 0.0208, Accuracy: 1032/10000 (10%)
#
# Train Epoch: 192 [0/50000 (0%)]	Loss: 0.414161
# Train Epoch: 192 [25600/50000 (51%)]	Loss: 0.539434
#
# Test set: Average loss: 0.0208, Accuracy: 1034/10000 (10%)
#
# Train Epoch: 193 [0/50000 (0%)]	Loss: 0.510865
# Train Epoch: 193 [25600/50000 (51%)]	Loss: 0.405738
#
# Test set: Average loss: 0.0211, Accuracy: 1025/10000 (10%)
#
# Train Epoch: 194 [0/50000 (0%)]	Loss: 0.478756
# Train Epoch: 194 [25600/50000 (51%)]	Loss: 0.503989
#
# Test set: Average loss: 0.0223, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 195 [0/50000 (0%)]	Loss: 0.434975
# Train Epoch: 195 [25600/50000 (51%)]	Loss: 0.481436
#
# Test set: Average loss: 0.0197, Accuracy: 1051/10000 (11%)
#
# Train Epoch: 196 [0/50000 (0%)]	Loss: 0.420089
# Train Epoch: 196 [25600/50000 (51%)]	Loss: 0.418062
#
# Test set: Average loss: 0.0209, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 197 [0/50000 (0%)]	Loss: 0.411812
# Train Epoch: 197 [25600/50000 (51%)]	Loss: 0.461375
#
# Test set: Average loss: 0.0210, Accuracy: 1019/10000 (10%)
#
# Train Epoch: 198 [0/50000 (0%)]	Loss: 0.425392
# Train Epoch: 198 [25600/50000 (51%)]	Loss: 0.399422
#
# Test set: Average loss: 0.0205, Accuracy: 1027/10000 (10%)
#
# Train Epoch: 199 [0/50000 (0%)]	Loss: 0.456014
# Train Epoch: 199 [25600/50000 (51%)]	Loss: 0.441401
#
# Test set: Average loss: 0.0204, Accuracy: 1021/10000 (10%)
#
# Train Epoch: 200 [0/50000 (0%)]	Loss: 0.328554
# Train Epoch: 200 [25600/50000 (51%)]	Loss: 0.438038
#
# Test set: Average loss: 0.0201, Accuracy: 1021/10000 (10%)
#
# Train Epoch: 201 [0/50000 (0%)]	Loss: 0.387121
# Train Epoch: 201 [25600/50000 (51%)]	Loss: 0.446075
#
# Test set: Average loss: 0.0202, Accuracy: 1027/10000 (10%)
#
# Train Epoch: 202 [0/50000 (0%)]	Loss: 0.406430
# Train Epoch: 202 [25600/50000 (51%)]	Loss: 0.409321
#
# Test set: Average loss: 0.0200, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 203 [0/50000 (0%)]	Loss: 0.430515
# Train Epoch: 203 [25600/50000 (51%)]	Loss: 0.548815
#
# Test set: Average loss: 0.0197, Accuracy: 1044/10000 (10%)
#
# Train Epoch: 204 [0/50000 (0%)]	Loss: 0.465939
# Train Epoch: 204 [25600/50000 (51%)]	Loss: 0.376792
#
# Test set: Average loss: 0.0202, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 205 [0/50000 (0%)]	Loss: 0.478211
# Train Epoch: 205 [25600/50000 (51%)]	Loss: 0.398445
#
# Test set: Average loss: 0.0200, Accuracy: 1043/10000 (10%)
#
# Train Epoch: 206 [0/50000 (0%)]	Loss: 0.381422
# Train Epoch: 206 [25600/50000 (51%)]	Loss: 0.565797
#
# Test set: Average loss: 0.0206, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 207 [0/50000 (0%)]	Loss: 0.426280
# Train Epoch: 207 [25600/50000 (51%)]	Loss: 0.357049
#
# Test set: Average loss: 0.0201, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 208 [0/50000 (0%)]	Loss: 0.440187
# Train Epoch: 208 [25600/50000 (51%)]	Loss: 0.332688
#
# Test set: Average loss: 0.0203, Accuracy: 1034/10000 (10%)
#
# Train Epoch: 209 [0/50000 (0%)]	Loss: 0.431564
# Train Epoch: 209 [25600/50000 (51%)]	Loss: 0.442566
#
# Test set: Average loss: 0.0208, Accuracy: 1031/10000 (10%)
#
# Train Epoch: 210 [0/50000 (0%)]	Loss: 0.403933
# Train Epoch: 210 [25600/50000 (51%)]	Loss: 0.406070
#
# Test set: Average loss: 0.0200, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 211 [0/50000 (0%)]	Loss: 0.464501
# Train Epoch: 211 [25600/50000 (51%)]	Loss: 0.424558
#
# Test set: Average loss: 0.0198, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 212 [0/50000 (0%)]	Loss: 0.433308
# Train Epoch: 212 [25600/50000 (51%)]	Loss: 0.465655
#
# Test set: Average loss: 0.0201, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 213 [0/50000 (0%)]	Loss: 0.364777
# Train Epoch: 213 [25600/50000 (51%)]	Loss: 0.506438
#
# Test set: Average loss: 0.0201, Accuracy: 1031/10000 (10%)
#
# Train Epoch: 214 [0/50000 (0%)]	Loss: 0.362970
# Train Epoch: 214 [25600/50000 (51%)]	Loss: 0.439207
#
# Test set: Average loss: 0.0206, Accuracy: 1032/10000 (10%)
#
# Train Epoch: 215 [0/50000 (0%)]	Loss: 0.489909
# Train Epoch: 215 [25600/50000 (51%)]	Loss: 0.418766
#
# Test set: Average loss: 0.0202, Accuracy: 1034/10000 (10%)
#
# Train Epoch: 216 [0/50000 (0%)]	Loss: 0.391613
# Train Epoch: 216 [25600/50000 (51%)]	Loss: 0.421158
#
# Test set: Average loss: 0.0199, Accuracy: 1031/10000 (10%)
#
# Train Epoch: 217 [0/50000 (0%)]	Loss: 0.385067
# Train Epoch: 217 [25600/50000 (51%)]	Loss: 0.469349
#
# Test set: Average loss: 0.0204, Accuracy: 1031/10000 (10%)
#
# Train Epoch: 218 [0/50000 (0%)]	Loss: 0.383868
# Train Epoch: 218 [25600/50000 (51%)]	Loss: 0.420967
#
# Test set: Average loss: 0.0203, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 219 [0/50000 (0%)]	Loss: 0.426389
# Train Epoch: 219 [25600/50000 (51%)]	Loss: 0.348571
#
# Test set: Average loss: 0.0200, Accuracy: 1029/10000 (10%)
#
# Train Epoch: 220 [0/50000 (0%)]	Loss: 0.432275
# Train Epoch: 220 [25600/50000 (51%)]	Loss: 0.468253
#
# Test set: Average loss: 0.0202, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 221 [0/50000 (0%)]	Loss: 0.382305
# Train Epoch: 221 [25600/50000 (51%)]	Loss: 0.406672
#
# Test set: Average loss: 0.0203, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 222 [0/50000 (0%)]	Loss: 0.446208
# Train Epoch: 222 [25600/50000 (51%)]	Loss: 0.460094
#
# Test set: Average loss: 0.0202, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 223 [0/50000 (0%)]	Loss: 0.375372
# Train Epoch: 223 [25600/50000 (51%)]	Loss: 0.512636
#
# Test set: Average loss: 0.0201, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 224 [0/50000 (0%)]	Loss: 0.389627
# Train Epoch: 224 [25600/50000 (51%)]	Loss: 0.375023
#
# Test set: Average loss: 0.0200, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 225 [0/50000 (0%)]	Loss: 0.388197
# Train Epoch: 225 [25600/50000 (51%)]	Loss: 0.444253
#
# Test set: Average loss: 0.0202, Accuracy: 1022/10000 (10%)
#
# Train Epoch: 226 [0/50000 (0%)]	Loss: 0.399975
# Train Epoch: 226 [25600/50000 (51%)]	Loss: 0.388293
#
# Test set: Average loss: 0.0204, Accuracy: 1031/10000 (10%)
#
# Train Epoch: 227 [0/50000 (0%)]	Loss: 0.419644
# Train Epoch: 227 [25600/50000 (51%)]	Loss: 0.368087
#
# Test set: Average loss: 0.0198, Accuracy: 1034/10000 (10%)
#
# Train Epoch: 228 [0/50000 (0%)]	Loss: 0.456923
# Train Epoch: 228 [25600/50000 (51%)]	Loss: 0.422215
#
# Test set: Average loss: 0.0202, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 229 [0/50000 (0%)]	Loss: 0.418350
# Train Epoch: 229 [25600/50000 (51%)]	Loss: 0.387635
#
# Test set: Average loss: 0.0199, Accuracy: 1032/10000 (10%)
#
# Train Epoch: 230 [0/50000 (0%)]	Loss: 0.403969
# Train Epoch: 230 [25600/50000 (51%)]	Loss: 0.399174
#
# Test set: Average loss: 0.0201, Accuracy: 1034/10000 (10%)
#
# Train Epoch: 231 [0/50000 (0%)]	Loss: 0.360727
# Train Epoch: 231 [25600/50000 (51%)]	Loss: 0.398979
#
# Test set: Average loss: 0.0201, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 232 [0/50000 (0%)]	Loss: 0.453411
# Train Epoch: 232 [25600/50000 (51%)]	Loss: 0.493800
#
# Test set: Average loss: 0.0201, Accuracy: 1037/10000 (10%)
#
# Train Epoch: 233 [0/50000 (0%)]	Loss: 0.483515
# Train Epoch: 233 [25600/50000 (51%)]	Loss: 0.434306
#
# Test set: Average loss: 0.0201, Accuracy: 1035/10000 (10%)
#
# Train Epoch: 234 [0/50000 (0%)]	Loss: 0.404999
# Train Epoch: 234 [25600/50000 (51%)]	Loss: 0.406037
#
# Test set: Average loss: 0.0202, Accuracy: 1032/10000 (10%)
#
# Train Epoch: 235 [0/50000 (0%)]	Loss: 0.387951
# Train Epoch: 235 [25600/50000 (51%)]	Loss: 0.362271
#
# Test set: Average loss: 0.0201, Accuracy: 1039/10000 (10%)
#
# Train Epoch: 236 [0/50000 (0%)]	Loss: 0.436558
# Train Epoch: 236 [25600/50000 (51%)]	Loss: 0.335443
#
# Test set: Average loss: 0.0204, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 237 [0/50000 (0%)]	Loss: 0.445172
# Train Epoch: 237 [25600/50000 (51%)]	Loss: 0.400586
#
# Test set: Average loss: 0.0205, Accuracy: 1025/10000 (10%)
#
# Train Epoch: 238 [0/50000 (0%)]	Loss: 0.437612
# Train Epoch: 238 [25600/50000 (51%)]	Loss: 0.421622
#
# Test set: Average loss: 0.0204, Accuracy: 1029/10000 (10%)
#
# Train Epoch: 239 [0/50000 (0%)]	Loss: 0.376713
# Train Epoch: 239 [25600/50000 (51%)]	Loss: 0.395032
#
# Test set: Average loss: 0.0204, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 240 [0/50000 (0%)]	Loss: 0.345051
# Train Epoch: 240 [25600/50000 (51%)]	Loss: 0.363723
#
# Test set: Average loss: 0.0206, Accuracy: 1025/10000 (10%)
#
# Train Epoch: 241 [0/50000 (0%)]	Loss: 0.408566
# Train Epoch: 241 [25600/50000 (51%)]	Loss: 0.454477
#
# Test set: Average loss: 0.0203, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 242 [0/50000 (0%)]	Loss: 0.442912
# Train Epoch: 242 [25600/50000 (51%)]	Loss: 0.444809
#
# Test set: Average loss: 0.0203, Accuracy: 1034/10000 (10%)
#
# Train Epoch: 243 [0/50000 (0%)]	Loss: 0.400951
# Train Epoch: 243 [25600/50000 (51%)]	Loss: 0.347786
#
# Test set: Average loss: 0.0204, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 244 [0/50000 (0%)]	Loss: 0.458577
# Train Epoch: 244 [25600/50000 (51%)]	Loss: 0.386405
#
# Test set: Average loss: 0.0202, Accuracy: 1029/10000 (10%)
#
# Train Epoch: 245 [0/50000 (0%)]	Loss: 0.438283
# Train Epoch: 245 [25600/50000 (51%)]	Loss: 0.428337
#
# Test set: Average loss: 0.0206, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 246 [0/50000 (0%)]	Loss: 0.356794
# Train Epoch: 246 [25600/50000 (51%)]	Loss: 0.352630
#
# Test set: Average loss: 0.0202, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 247 [0/50000 (0%)]	Loss: 0.458222
# Train Epoch: 247 [25600/50000 (51%)]	Loss: 0.454606
#
# Test set: Average loss: 0.0203, Accuracy: 1024/10000 (10%)
#
# Train Epoch: 248 [0/50000 (0%)]	Loss: 0.469277
# Train Epoch: 248 [25600/50000 (51%)]	Loss: 0.416294
#
# Test set: Average loss: 0.0203, Accuracy: 1025/10000 (10%)
#
# Train Epoch: 249 [0/50000 (0%)]	Loss: 0.420369
# Train Epoch: 249 [25600/50000 (51%)]	Loss: 0.365839
#
# Test set: Average loss: 0.0201, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 250 [0/50000 (0%)]	Loss: 0.414151
# Train Epoch: 250 [25600/50000 (51%)]	Loss: 0.436534
#
# Test set: Average loss: 0.0203, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 251 [0/50000 (0%)]	Loss: 0.431190
# Train Epoch: 251 [25600/50000 (51%)]	Loss: 0.404780
#
# Test set: Average loss: 0.0207, Accuracy: 1023/10000 (10%)
#
# Train Epoch: 252 [0/50000 (0%)]	Loss: 0.391818
# Train Epoch: 252 [25600/50000 (51%)]	Loss: 0.440156
#
# Test set: Average loss: 0.0203, Accuracy: 1029/10000 (10%)
#
# Train Epoch: 253 [0/50000 (0%)]	Loss: 0.406120
# Train Epoch: 253 [25600/50000 (51%)]	Loss: 0.403781
#
# Test set: Average loss: 0.0205, Accuracy: 1022/10000 (10%)
#
# Train Epoch: 254 [0/50000 (0%)]	Loss: 0.377515
# Train Epoch: 254 [25600/50000 (51%)]	Loss: 0.421977
#
# Test set: Average loss: 0.0205, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 255 [0/50000 (0%)]	Loss: 0.414058
# Train Epoch: 255 [25600/50000 (51%)]	Loss: 0.366670
#
# Test set: Average loss: 0.0206, Accuracy: 1029/10000 (10%)
#
# Train Epoch: 256 [0/50000 (0%)]	Loss: 0.426737
# Train Epoch: 256 [25600/50000 (51%)]	Loss: 0.354346
#
# Test set: Average loss: 0.0208, Accuracy: 1025/10000 (10%)
#
# Train Epoch: 257 [0/50000 (0%)]	Loss: 0.446418
# Train Epoch: 257 [25600/50000 (51%)]	Loss: 0.467894
#
# Test set: Average loss: 0.0205, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 258 [0/50000 (0%)]	Loss: 0.357925
# Train Epoch: 258 [25600/50000 (51%)]	Loss: 0.352761
#
# Test set: Average loss: 0.0206, Accuracy: 1024/10000 (10%)
#
# Train Epoch: 259 [0/50000 (0%)]	Loss: 0.304011
# Train Epoch: 259 [25600/50000 (51%)]	Loss: 0.420327
#
# Test set: Average loss: 0.0205, Accuracy: 1030/10000 (10%)
#
# Train Epoch: 260 [0/50000 (0%)]	Loss: 0.383354
# Train Epoch: 260 [25600/50000 (51%)]	Loss: 0.384909
#
# Test set: Average loss: 0.0205, Accuracy: 1027/10000 (10%)
#
# Train Epoch: 261 [0/50000 (0%)]	Loss: 0.366264
# Train Epoch: 261 [25600/50000 (51%)]	Loss: 0.437101
#
# Test set: Average loss: 0.0203, Accuracy: 1028/10000 (10%)
#
# Train Epoch: 262 [0/50000 (0%)]	Loss: 0.479669
# Train Epoch: 262 [25600/50000 (51%)]	Loss: 0.490482
#
# Test set: Average loss: 0.0204, Accuracy: 1024/10000 (10%)
#
# Train Epoch: 263 [0/50000 (0%)]	Loss: 0.304626
# Train Epoch: 263 [25600/50000 (51%)]	Loss: 0.443627
#
# Test set: Average loss: 0.0203, Accuracy: 1025/10000 (10%)
#
# Train Epoch: 264 [0/50000 (0%)]	Loss: 0.378090
# Train Epoch: 264 [25600/50000 (51%)]	Loss: 0.403055
#
# Test set: Average loss: 0.0207, Accuracy: 1021/10000 (10%)
#
# Train Epoch: 265 [0/50000 (0%)]	Loss: 0.392176
# Train Epoch: 265 [25600/50000 (51%)]	Loss: 0.456765
#
# Test set: Average loss: 0.0207, Accuracy: 1021/10000 (10%)
#
# Train Epoch: 266 [0/50000 (0%)]	Loss: 0.451612
# Train Epoch: 266 [25600/50000 (51%)]	Loss: 0.326999
#
# Test set: Average loss: 0.0205, Accuracy: 1024/10000 (10%)
#
# Train Epoch: 267 [0/50000 (0%)]	Loss: 0.411344
# Train Epoch: 267 [25600/50000 (51%)]	Loss: 0.418176
#
# Test set: Average loss: 0.0204, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 268 [0/50000 (0%)]	Loss: 0.339901
# Train Epoch: 268 [25600/50000 (51%)]	Loss: 0.412666
#
# Test set: Average loss: 0.0203, Accuracy: 1032/10000 (10%)
#
# Train Epoch: 269 [0/50000 (0%)]	Loss: 0.363345
# Train Epoch: 269 [25600/50000 (51%)]	Loss: 0.408145
#
# ...
#
# Train Epoch: 1 [0/50000 (0%)]	Loss: 1.829167
# Train Epoch: 1 [25600/50000 (51%)]	Loss: 1.562400
#
# Test set: Average loss: 0.0159, Accuracy: 2955/10000 (30%)
#
# Train Epoch: 2 [0/50000 (0%)]	Loss: 1.566526
# Train Epoch: 2 [25600/50000 (51%)]	Loss: 1.492627
#
# Test set: Average loss: 0.0152, Accuracy: 3695/10000 (37%)
#
# Train Epoch: 3 [0/50000 (0%)]	Loss: 1.486677
# Train Epoch: 3 [25600/50000 (51%)]	Loss: 1.373957
#
# Test set: Average loss: 0.0149, Accuracy: 3693/10000 (37%)
#
# Train Epoch: 4 [0/50000 (0%)]	Loss: 1.318871
# Train Epoch: 4 [25600/50000 (51%)]	Loss: 1.329089
#
# Test set: Average loss: 0.0154, Accuracy: 3325/10000 (33%)
#
# Train Epoch: 5 [0/50000 (0%)]	Loss: 1.334317
# Train Epoch: 5 [25600/50000 (51%)]	Loss: 1.314658
#
# Test set: Average loss: 0.0157, Accuracy: 3097/10000 (31%)
#
# Train Epoch: 6 [0/50000 (0%)]	Loss: 1.297782
# Train Epoch: 6 [25600/50000 (51%)]	Loss: 1.192751
#
# Test set: Average loss: 0.0162, Accuracy: 2925/10000 (29%)
#
# Train Epoch: 7 [0/50000 (0%)]	Loss: 1.298899
# Train Epoch: 7 [25600/50000 (51%)]	Loss: 1.272758
#
# Test set: Average loss: 0.0169, Accuracy: 2588/10000 (26%)
#
# Train Epoch: 8 [0/50000 (0%)]	Loss: 1.170378
# Train Epoch: 8 [25600/50000 (51%)]	Loss: 1.231176
#
# Test set: Average loss: 0.0173, Accuracy: 2572/10000 (26%)
#
# Train Epoch: 9 [0/50000 (0%)]	Loss: 1.134943
# Train Epoch: 9 [25600/50000 (51%)]	Loss: 1.071338
#
# Test set: Average loss: 0.0180, Accuracy: 2658/10000 (27%)
#
# Train Epoch: 10 [0/50000 (0%)]	Loss: 1.084160
# Train Epoch: 10 [25600/50000 (51%)]	Loss: 1.165182
#
# Test set: Average loss: 0.0190, Accuracy: 2056/10000 (21%)
#
# Train Epoch: 11 [0/50000 (0%)]	Loss: 0.970511
# Train Epoch: 11 [25600/50000 (51%)]	Loss: 1.085987
#
# Test set: Average loss: 0.0180, Accuracy: 2066/10000 (21%)
#
# Train Epoch: 12 [0/50000 (0%)]	Loss: 1.144472
# Train Epoch: 12 [25600/50000 (51%)]	Loss: 1.086894
#
# Test set: Average loss: 0.0202, Accuracy: 1428/10000 (14%)
#
# Train Epoch: 13 [0/50000 (0%)]	Loss: 0.976336
# Train Epoch: 13 [25600/50000 (51%)]	Loss: 1.049779
#
# Test set: Average loss: 0.0197, Accuracy: 1289/10000 (13%)
#
# Train Epoch: 14 [0/50000 (0%)]	Loss: 0.950758
# Train Epoch: 14 [25600/50000 (51%)]	Loss: 1.029046
#
# Test set: Average loss: 0.0217, Accuracy: 1394/10000 (14%)
#
# Train Epoch: 15 [0/50000 (0%)]	Loss: 0.920477
# Train Epoch: 15 [25600/50000 (51%)]	Loss: 1.009119
#
# Test set: Average loss: 0.0187, Accuracy: 2214/10000 (22%)
#
# Train Epoch: 16 [0/50000 (0%)]	Loss: 1.009931
# Train Epoch: 16 [25600/50000 (51%)]	Loss: 0.884074
#
# Test set: Average loss: 0.0205, Accuracy: 1842/10000 (18%)
#
# Train Epoch: 17 [0/50000 (0%)]	Loss: 1.060509
# Train Epoch: 17 [25600/50000 (51%)]	Loss: 1.091936
#
# Test set: Average loss: 0.0202, Accuracy: 1904/10000 (19%)
#
# Train Epoch: 18 [0/50000 (0%)]	Loss: 0.956667
# Train Epoch: 18 [25600/50000 (51%)]	Loss: 1.032263
#
# Test set: Average loss: 0.0225, Accuracy: 1668/10000 (17%)
#
# Train Epoch: 19 [0/50000 (0%)]	Loss: 0.955529
# Train Epoch: 19 [25600/50000 (51%)]	Loss: 1.038660
#
# Test set: Average loss: 0.0217, Accuracy: 1712/10000 (17%)
#
# Train Epoch: 20 [0/50000 (0%)]	Loss: 0.954422
# Train Epoch: 20 [25600/50000 (51%)]	Loss: 0.827217
#
# Test set: Average loss: 0.0216, Accuracy: 1680/10000 (17%)
#
# Train Epoch: 21 [0/50000 (0%)]	Loss: 0.928747
# Train Epoch: 21 [25600/50000 (51%)]	Loss: 0.933106
#
# Test set: Average loss: 0.0223, Accuracy: 2014/10000 (20%)
#
# Train Epoch: 22 [0/50000 (0%)]	Loss: 0.938110
# Train Epoch: 22 [25600/50000 (51%)]	Loss: 0.813348
#
# Test set: Average loss: 0.0216, Accuracy: 1718/10000 (17%)
#
# Train Epoch: 23 [0/50000 (0%)]	Loss: 0.858488
# Train Epoch: 23 [25600/50000 (51%)]	Loss: 0.848062
#
# Test set: Average loss: 0.0220, Accuracy: 1219/10000 (12%)
#
# Train Epoch: 24 [0/50000 (0%)]	Loss: 0.836311
# Train Epoch: 24 [25600/50000 (51%)]	Loss: 0.915571
#
# Test set: Average loss: 0.0212, Accuracy: 1226/10000 (12%)
#
# Train Epoch: 25 [0/50000 (0%)]	Loss: 0.953837
# Train Epoch: 25 [25600/50000 (51%)]	Loss: 0.841301
#
# Test set: Average loss: 0.0232, Accuracy: 1072/10000 (11%)
#
# Train Epoch: 26 [0/50000 (0%)]	Loss: 0.858026
# Train Epoch: 26 [25600/50000 (51%)]	Loss: 0.846071
#
# Test set: Average loss: 0.0232, Accuracy: 1278/10000 (13%)
#
# Train Epoch: 27 [0/50000 (0%)]	Loss: 0.802240
# Train Epoch: 27 [25600/50000 (51%)]	Loss: 0.877444
#
# Test set: Average loss: 0.0219, Accuracy: 1312/10000 (13%)
#
# Train Epoch: 28 [0/50000 (0%)]	Loss: 0.930521
# Train Epoch: 28 [25600/50000 (51%)]	Loss: 0.785081
#
# Test set: Average loss: 0.0223, Accuracy: 1571/10000 (16%)
#
# Train Epoch: 29 [0/50000 (0%)]	Loss: 0.709777
# Train Epoch: 29 [25600/50000 (51%)]	Loss: 0.881133
#
# Test set: Average loss: 0.0232, Accuracy: 1335/10000 (13%)
#
# Train Epoch: 30 [0/50000 (0%)]	Loss: 0.783508
# Train Epoch: 30 [25600/50000 (51%)]	Loss: 0.908937
#
# Test set: Average loss: 0.0245, Accuracy: 1080/10000 (11%)
#
# Train Epoch: 31 [0/50000 (0%)]	Loss: 0.745324
# Train Epoch: 31 [25600/50000 (51%)]	Loss: 0.777501
#
# Test set: Average loss: 0.0263, Accuracy: 1049/10000 (10%)
#
# Train Epoch: 32 [0/50000 (0%)]	Loss: 0.834120
# Train Epoch: 32 [25600/50000 (51%)]	Loss: 0.837024
#
# Test set: Average loss: 0.0251, Accuracy: 1098/10000 (11%)
#
# Train Epoch: 33 [0/50000 (0%)]	Loss: 0.855328
# Train Epoch: 33 [25600/50000 (51%)]	Loss: 0.815736
#
# Test set: Average loss: 0.0225, Accuracy: 1559/10000 (16%)
#
# Train Epoch: 34 [0/50000 (0%)]	Loss: 0.925766
# Train Epoch: 34 [25600/50000 (51%)]	Loss: 0.817787
#
# Test set: Average loss: 0.0233, Accuracy: 1297/10000 (13%)
#
# Train Epoch: 35 [0/50000 (0%)]	Loss: 0.869812
# Train Epoch: 35 [25600/50000 (51%)]	Loss: 0.806617
#
# Test set: Average loss: 0.0228, Accuracy: 1364/10000 (14%)
#
# Train Epoch: 36 [0/50000 (0%)]	Loss: 0.824429
# Train Epoch: 36 [25600/50000 (51%)]	Loss: 0.750470
#
# Test set: Average loss: 0.0229, Accuracy: 1216/10000 (12%)
#
# Train Epoch: 37 [0/50000 (0%)]	Loss: 0.703119
# Train Epoch: 37 [25600/50000 (51%)]	Loss: 0.742330
#
# Test set: Average loss: 0.0234, Accuracy: 1143/10000 (11%)
#
# Train Epoch: 38 [0/50000 (0%)]	Loss: 0.686163
# Train Epoch: 38 [25600/50000 (51%)]	Loss: 0.684179
#
# Test set: Average loss: 0.0226, Accuracy: 1061/10000 (11%)
#
# Train Epoch: 39 [0/50000 (0%)]	Loss: 0.705672
# Train Epoch: 39 [25600/50000 (51%)]	Loss: 0.977790
#
# Test set: Average loss: 0.0241, Accuracy: 1069/10000 (11%)
#
# Train Epoch: 40 [0/50000 (0%)]	Loss: 0.709861
# Train Epoch: 40 [25600/50000 (51%)]	Loss: 0.693252
#
# Test set: Average loss: 0.0242, Accuracy: 1072/10000 (11%)
#
# Train Epoch: 41 [0/50000 (0%)]	Loss: 0.741900
# Train Epoch: 41 [25600/50000 (51%)]	Loss: 0.753138
#
# Test set: Average loss: 0.0229, Accuracy: 1063/10000 (11%)
#
# Train Epoch: 42 [0/50000 (0%)]	Loss: 0.775545
# Train Epoch: 42 [25600/50000 (51%)]	Loss: 0.701996
#
# Test set: Average loss: 0.0255, Accuracy: 1013/10000 (10%)
#
# Train Epoch: 43 [0/50000 (0%)]	Loss: 0.787646
# Train Epoch: 43 [25600/50000 (51%)]	Loss: 0.852164
#
# Test set: Average loss: 0.0241, Accuracy: 1121/10000 (11%)
#
# Train Epoch: 44 [0/50000 (0%)]	Loss: 0.730475
# Train Epoch: 44 [25600/50000 (51%)]	Loss: 0.639953
#
# Test set: Average loss: 0.0221, Accuracy: 1349/10000 (13%)
#
# Train Epoch: 45 [0/50000 (0%)]	Loss: 0.872913
# Train Epoch: 45 [25600/50000 (51%)]	Loss: 0.700020
#
# Test set: Average loss: 0.0241, Accuracy: 1026/10000 (10%)
#
# Train Epoch: 46 [0/50000 (0%)]	Loss: 0.609222
# Train Epoch: 46 [25600/50000 (51%)]	Loss: 0.880310
#
# Test set: Average loss: 0.0235, Accuracy: 1065/10000 (11%)
#
# Train Epoch: 47 [0/50000 (0%)]	Loss: 0.690096
# Train Epoch: 47 [25600/50000 (51%)]	Loss: 0.716163
#
# Test set: Average loss: 0.0235, Accuracy: 1099/10000 (11%)
#
# Train Epoch: 48 [0/50000 (0%)]	Loss: 0.641568
# Train Epoch: 48 [25600/50000 (51%)]	Loss: 0.706241
#
# Test set: Average loss: 0.0236, Accuracy: 1069/10000 (11%)
#
# Train Epoch: 49 [0/50000 (0%)]	Loss: 0.660723
# Train Epoch: 49 [25600/50000 (51%)]	Loss: 0.784087
#
# Test set: Average loss: 0.0248, Accuracy: 1011/10000 (10%)
#
# Train Epoch: 50 [0/50000 (0%)]	Loss: 0.756653
# Train Epoch: 50 [25600/50000 (51%)]	Loss: 0.669067
#
# Test set: Average loss: 0.0255, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 51 [0/50000 (0%)]	Loss: 0.759844
# Train Epoch: 51 [25600/50000 (51%)]	Loss: 0.779548
#
# Test set: Average loss: 0.0224, Accuracy: 1067/10000 (11%)
#
# Train Epoch: 52 [0/50000 (0%)]	Loss: 0.641617
# Train Epoch: 52 [25600/50000 (51%)]	Loss: 0.618712
#
# Test set: Average loss: 0.0250, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 53 [0/50000 (0%)]	Loss: 0.655764
# Train Epoch: 53 [25600/50000 (51%)]	Loss: 0.640950
#
# Test set: Average loss: 0.0249, Accuracy: 1012/10000 (10%)
#
# Train Epoch: 54 [0/50000 (0%)]	Loss: 0.711285
# Train Epoch: 54 [25600/50000 (51%)]	Loss: 0.752761
#
# Test set: Average loss: 0.0238, Accuracy: 1008/10000 (10%)
#
# Train Epoch: 55 [0/50000 (0%)]	Loss: 0.597901
# Train Epoch: 55 [25600/50000 (51%)]	Loss: 0.630649
#
# Test set: Average loss: 0.0244, Accuracy: 1015/10000 (10%)
#
# Train Epoch: 56 [0/50000 (0%)]	Loss: 0.690434
# Train Epoch: 56 [25600/50000 (51%)]	Loss: 0.689618
#
# Test set: Average loss: 0.0252, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 57 [0/50000 (0%)]	Loss: 0.773756
# Train Epoch: 57 [25600/50000 (51%)]	Loss: 0.668821
#
# Test set: Average loss: 0.0235, Accuracy: 1045/10000 (10%)
#
# Train Epoch: 58 [0/50000 (0%)]	Loss: 0.695547
# Train Epoch: 58 [25600/50000 (51%)]	Loss: 0.614333
#
# Test set: Average loss: 0.0243, Accuracy: 1010/10000 (10%)
#
# Train Epoch: 59 [0/50000 (0%)]	Loss: 0.673885
# Train Epoch: 59 [25600/50000 (51%)]	Loss: 0.660126
#
# Test set: Average loss: 0.0246, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 60 [0/50000 (0%)]	Loss: 0.588686
# Train Epoch: 60 [25600/50000 (51%)]	Loss: 0.754670
#
# Test set: Average loss: 0.0245, Accuracy: 1005/10000 (10%)
#
# Train Epoch: 61 [0/50000 (0%)]	Loss: 0.555964
# Train Epoch: 61 [25600/50000 (51%)]	Loss: 0.691406
#
# Test set: Average loss: 0.0228, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 62 [0/50000 (0%)]	Loss: 0.639802
# Train Epoch: 62 [25600/50000 (51%)]	Loss: 0.629714
#
# Test set: Average loss: 0.0259, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 63 [0/50000 (0%)]	Loss: 0.674566
# Train Epoch: 63 [25600/50000 (51%)]	Loss: 0.739053
#
# Test set: Average loss: 0.0263, Accuracy: 1007/10000 (10%)
#
# Train Epoch: 64 [0/50000 (0%)]	Loss: 0.700173
# Train Epoch: 64 [25600/50000 (51%)]	Loss: 0.696405
#
# Test set: Average loss: 0.0249, Accuracy: 1021/10000 (10%)
#
# Train Epoch: 65 [0/50000 (0%)]	Loss: 0.613261
# Train Epoch: 65 [25600/50000 (51%)]	Loss: 0.563453
#
# Test set: Average loss: 0.0233, Accuracy: 1252/10000 (13%)
#
# Train Epoch: 66 [0/50000 (0%)]	Loss: 0.730136
# Train Epoch: 66 [25600/50000 (51%)]	Loss: 0.626725
#
# Test set: Average loss: 0.0237, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 67 [0/50000 (0%)]	Loss: 0.598881
# Train Epoch: 67 [25600/50000 (51%)]	Loss: 0.741266
#
# Test set: Average loss: 0.0264, Accuracy: 1001/10000 (10%)
#
# Train Epoch: 68 [0/50000 (0%)]	Loss: 0.672969
# Train Epoch: 68 [25600/50000 (51%)]	Loss: 0.609756
#
# Test set: Average loss: 0.0252, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 69 [0/50000 (0%)]	Loss: 0.520051
# Train Epoch: 69 [25600/50000 (51%)]	Loss: 0.526308
#
# Test set: Average loss: 0.0251, Accuracy: 1003/10000 (10%)
#
# Train Epoch: 70 [0/50000 (0%)]	Loss: 0.640241
# Train Epoch: 70 [25600/50000 (51%)]	Loss: 0.722668
#
# Test set: Average loss: 0.0245, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 71 [0/50000 (0%)]	Loss: 0.689777
# Train Epoch: 71 [25600/50000 (51%)]	Loss: 0.653493
#
# Test set: Average loss: 0.0243, Accuracy: 1484/10000 (15%)
#
# Train Epoch: 72 [0/50000 (0%)]	Loss: 0.572781
# Train Epoch: 72 [25600/50000 (51%)]	Loss: 0.667584
#
# Test set: Average loss: 0.0238, Accuracy: 1040/10000 (10%)
#
# Train Epoch: 73 [0/50000 (0%)]	Loss: 0.591881
# Train Epoch: 73 [25600/50000 (51%)]	Loss: 0.589711
#
# Test set: Average loss: 0.0233, Accuracy: 1003/10000 (10%)
#
# Train Epoch: 74 [0/50000 (0%)]	Loss: 0.682340
# Train Epoch: 74 [25600/50000 (51%)]	Loss: 0.626270
#
# Test set: Average loss: 0.0239, Accuracy: 1001/10000 (10%)
#
# Train Epoch: 75 [0/50000 (0%)]	Loss: 0.557988
# Train Epoch: 75 [25600/50000 (51%)]	Loss: 0.568491
#
# Test set: Average loss: 0.0237, Accuracy: 1033/10000 (10%)
#
# Train Epoch: 76 [0/50000 (0%)]	Loss: 0.641472
# Train Epoch: 76 [25600/50000 (51%)]	Loss: 0.691597
#
# Test set: Average loss: 0.0253, Accuracy: 1004/10000 (10%)
#
# Train Epoch: 77 [0/50000 (0%)]	Loss: 0.607756
# Train Epoch: 77 [25600/50000 (51%)]	Loss: 0.673042
#
# Test set: Average loss: 0.0252, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 78 [0/50000 (0%)]	Loss: 0.727695
# Train Epoch: 78 [25600/50000 (51%)]	Loss: 0.530028
#
# Test set: Average loss: 0.0246, Accuracy: 1001/10000 (10%)
#
# Train Epoch: 79 [0/50000 (0%)]	Loss: 0.632758
# Train Epoch: 79 [25600/50000 (51%)]	Loss: 0.569005
#
# Test set: Average loss: 0.0239, Accuracy: 1008/10000 (10%)
#
# Train Epoch: 80 [0/50000 (0%)]	Loss: 0.586725
# Train Epoch: 80 [25600/50000 (51%)]	Loss: 0.579061
#
# Test set: Average loss: 0.0242, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 81 [0/50000 (0%)]	Loss: 0.626997
# Train Epoch: 81 [25600/50000 (51%)]	Loss: 0.636909
#
# Test set: Average loss: 0.0248, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 82 [0/50000 (0%)]	Loss: 0.512223
# Train Epoch: 82 [25600/50000 (51%)]	Loss: 0.731994
#
# Test set: Average loss: 0.0240, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 83 [0/50000 (0%)]	Loss: 0.559977
# Train Epoch: 83 [25600/50000 (51%)]	Loss: 0.571829
#
# Test set: Average loss: 0.0243, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 84 [0/50000 (0%)]	Loss: 0.622095
# Train Epoch: 84 [25600/50000 (51%)]	Loss: 0.622618
#
# Test set: Average loss: 0.0242, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 85 [0/50000 (0%)]	Loss: 0.545767
# Train Epoch: 85 [25600/50000 (51%)]	Loss: 0.558380
#
# Test set: Average loss: 0.0258, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 86 [0/50000 (0%)]	Loss: 0.691555
# Train Epoch: 86 [25600/50000 (51%)]	Loss: 0.521651
#
# Test set: Average loss: 0.0246, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 87 [0/50000 (0%)]	Loss: 0.635729
# Train Epoch: 87 [25600/50000 (51%)]	Loss: 0.660510
#
# Test set: Average loss: 0.0246, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 88 [0/50000 (0%)]	Loss: 0.632419
# Train Epoch: 88 [25600/50000 (51%)]	Loss: 0.541822
#
# Test set: Average loss: 0.0253, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 89 [0/50000 (0%)]	Loss: 0.526078
# Train Epoch: 89 [25600/50000 (51%)]	Loss: 0.679734
#
# Test set: Average loss: 0.0243, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 90 [0/50000 (0%)]	Loss: 0.600335
# Train Epoch: 90 [25600/50000 (51%)]	Loss: 0.658135
#
# Test set: Average loss: 0.0253, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 91 [0/50000 (0%)]	Loss: 0.575088
# Train Epoch: 91 [25600/50000 (51%)]	Loss: 0.663807
#
# Test set: Average loss: 0.0242, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 92 [0/50000 (0%)]	Loss: 0.586753
# Train Epoch: 92 [25600/50000 (51%)]	Loss: 0.597386
#
# Test set: Average loss: 0.0254, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 93 [0/50000 (0%)]	Loss: 0.643382
# Train Epoch: 93 [25600/50000 (51%)]	Loss: 0.718616
#
# Test set: Average loss: 0.0253, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 94 [0/50000 (0%)]	Loss: 0.574945
# Train Epoch: 94 [25600/50000 (51%)]	Loss: 0.569890
#
# Test set: Average loss: 0.0234, Accuracy: 1011/10000 (10%)
#
# Train Epoch: 95 [0/50000 (0%)]	Loss: 0.642743
# Train Epoch: 95 [25600/50000 (51%)]	Loss: 0.535611
#
# Test set: Average loss: 0.0243, Accuracy: 1009/10000 (10%)
#
# Train Epoch: 96 [0/50000 (0%)]	Loss: 0.626867
# Train Epoch: 96 [25600/50000 (51%)]	Loss: 0.645594
#
# Test set: Average loss: 0.0235, Accuracy: 1006/10000 (10%)
#
# Train Epoch: 97 [0/50000 (0%)]	Loss: 0.586289
# Train Epoch: 97 [25600/50000 (51%)]	Loss: 0.573196
#
# Test set: Average loss: 0.0247, Accuracy: 1002/10000 (10%)
#
# Train Epoch: 98 [0/50000 (0%)]	Loss: 0.530386
# Train Epoch: 98 [25600/50000 (51%)]	Loss: 0.590555
#
# Test set: Average loss: 0.0256, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 99 [0/50000 (0%)]	Loss: 0.507809
# Train Epoch: 99 [25600/50000 (51%)]	Loss: 0.588545
#
# Test set: Average loss: 0.0242, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 100 [0/50000 (0%)]	Loss: 0.487767
# Train Epoch: 100 [25600/50000 (51%)]	Loss: 0.677558
#
# Test set: Average loss: 0.0252, Accuracy: 1000/10000 (10%)
#
# Train Epoch: 101 [0/50000 (0%)]	Loss: 0.499176
# Train Epoch: 101 [25600/50000 (51%)]	Loss: 0.690090
#
# Test set: Average loss: 0.0248, Accuracy: 1000/10000 (10%)
#
# Stop at acc of test set: 0.1
